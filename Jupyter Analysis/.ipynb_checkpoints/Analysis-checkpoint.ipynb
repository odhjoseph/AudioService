# %% [markdown]
# Records Audio, the zeroes in the array are somewhat questionable

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import matplotlib.pyplot as plt

#fs = 44100  # Sample rate
fs = 80000 
seconds = 5  

#myrecording = sd.rec(int(seconds * fs), samplerate=fs, channels=2)
myrecording = sd.playrec(myarray, fs, channels=2)
sd.wait()  
print(myrecording)
# Out:
# [[ 1.3545673e-07  4.5874308e-41]
#  [ 1.3545673e-07  4.5874308e-41]
#  [-8.5663749e+31  3.0914045e-41]
#  ...
#  [ 0.0000000e+00  9.5060921e+00]
#  [ 0.0000000e+00  9.5060959e+00]
#  [ 0.0000000e+00  9.5060997e+00]]

# %%
myrecording
# Out:
# array([[ 0.0000000e+00,  0.0000000e+00],
#        [ 0.0000000e+00,  0.0000000e+00],
#        [ 0.0000000e+00,  0.0000000e+00],
#        ...,
#        [ 6.1035156e-05, -6.9274902e-03],
#        [ 5.5541992e-03, -1.6632080e-02],
#        [ 6.3476562e-03, -8.3923340e-03]], dtype=float32)

# %%
plt.figure()
plt.plot(myrecording)
plt.xlabel("Sample Index")
plt.ylabel("Amplitude")
plt.title("Waveform")
plt.show()

# %%
fs = 80000 
seconds = 5  

#myrecording = sd.rec(int(seconds * fs), samplerate=fs, channels=2)
myrecording = sd.playrec(myarray, fs, channels=2)
print(myrecording)
sd.wait()
